# %% [markdown]
# #**Exercises 17**
#
# **Morphological methods, Convolution and Denoising (1400)**

# %% [markdown]
# 1- Apply the kernel to the image with erosion method. Use Zero-Padding method for padding. (300 points)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#insert padding

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#result output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#insert padding and output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#insert padding and output

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#insert padding and output

# %% [markdown]
# ![image.png](data:image/png;base64,...)
